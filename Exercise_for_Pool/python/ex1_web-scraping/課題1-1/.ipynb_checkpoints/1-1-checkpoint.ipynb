# %%
#店舗名、電話番号、メールアドレス、建物名
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re


url = 'https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW&p={}.format()'
max_page_index = 3
d_list = []
for i in range(max_page_index):
    acccess_url = url.format(i+1)

    r = requests.get(acccess_url)
    r.raise_for_status()

    soup = BeautifulSoup(r.content, 'lxml')

    food_stores =  soup.find_all('div', class_='style_restaurant__SeIVn')

    for food_store in food_stores:
        page_url = food_store.find('a').get('href')

        page_r = requests.get(page_url, timeout=3)
        page_r.raise_for_status()

        page_soup = BeautifulSoup(page_r.content, 'lxml')

        store_name = page_soup.select_one('#info-name').text

        phone_number = page_soup.select_one('#info-phone > td > ul > li:nth-child(1) > span.number').text


        store_building = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.locality')

        if store_building:
            building_name = store_building.text
        else:
            building_name = ''


        store_address = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.region').text
        
        def divide_addess(address):
            matches = re.match(r'(...??[都道府県])((?:旭川|伊達|石狩|盛岡|奥州|田村|南相馬|那須塩原|東村山|武蔵村山|羽村|十日町|上越|富山|野々市|大町|蒲郡|四日市|姫路|大和郡山|廿日市|下松|岩国|田川|大村)市|.+?郡(?:玉村|大町|.+?)[町村]|.+?市.+?区|.+?[市区町村])(.+)' , address)
            address1 = matches[1]
            address2 = matches[2]
            address3 = matches[3]



        if __name__ == '__main__':
            address = store_address
            divide_addess(address)
            


        d_list.append({
            '店舗名':store_name,
            '電話番号':phone_number,
            'メールアドレス':'',
            '建物名':building_name,
        })


df0 = pd.DataFrame(d_list)
# df.to_csv('sample.csv', index=None, encoding='utf-8-sig')

# %%
df0
# Out:
#                                            店舗名           電話番号 メールアドレス  \
# 0                        居酒屋 土間土間 渋谷文化村通り109前店  050-5485-3597
# 1   貸切＆パーティーダイニング HASSO CAFFE with PRONTO 神保町店  050-5486-6451
# 2                           PRONTO 野村不動産天王洲ビル店  050-5492-7021
# 3                  羽根つき焼きおにぎり専門店＆LABAR gao－ガオ－  070-8419-2331
# 4                                    日高屋 戸越銀座店   03-3782-0466
# 5                                 日高屋 高円寺北口駅前店   03-3223-2130
# 6                                    日高屋 蔵前駅前店   03-3865-5331
# 7                                  日高屋 大塚北口駅前店   03-3910-8857
# 8                                        松井製麺所  050-5486-9446
# 9                                  日高屋 高幡不動駅前店   042-592-2220
# 10                                 日高屋 押上四ツ目通店   03-5608-0302
# 11                                  日高屋 板橋駅西口店   03-3963-2455
# 12                                  日高屋 久米川南口店   042-395-6773
# 13                                   日高屋 春日駅前店   03-3814-6347
# 14                               日高屋 成城学園前駅北口店   03-3484-4777
# 15                                  日高屋 西大井駅前店   03-3778-2210
# 16                                   日高屋 大泉学園店   03-3978-5517
# 17                                   日高屋 新橋駅前店   03-3431-0025
# 18                                 日高屋 西日暮里東口店   03-3801-4678
# 19                                日高屋 三鷹南口中央通店   0422-47-7751
# 20                       居酒屋 土間土間 渋谷文化村通り109前店  050-5485-3597
# 21  貸切＆パーティーダイニング HASSO CAFFE with PRONTO 神保町店  050-5486-6451
# 22                          PRONTO 野村不動産天王洲ビル店  050-5492-7021
# 23                 羽根つき焼きおにぎり専門店＆LABAR gao－ガオ－  070-8419-2331
# 24                                   日高屋 戸越銀座店   03-3782-0466
# 25                                日高屋 高円寺北口駅前店   03-3223-2130
# 26                                   日高屋 蔵前駅前店   03-3865-5331
# 27                                 日高屋 大塚北口駅前店   03-3910-8857
# 28                                       松井製麺所  050-5486-9446
# 29                                 日高屋 高幡不動駅前店   042-592-2220
# 30                                 日高屋 押上四ツ目通店   03-5608-0302
# 31                                  日高屋 板橋駅西口店   03-3963-2455
# 32                                  日高屋 久米川南口店   042-395-6773
# 33                                   日高屋 春日駅前店   03-3814-6347
# 34                               日高屋 成城学園前駅北口店   03-3484-4777
# 35                                  日高屋 西大井駅前店   03-3778-2210
# 36                                   日高屋 大泉学園店   03-3978-5517
# 37                                   日高屋 新橋駅前店   03-3431-0025
# 38                                 日高屋 西日暮里東口店   03-3801-4678
# 39                                日高屋 三鷹南口中央通店   0422-47-7751
# 40                       居酒屋 土間土間 渋谷文化村通り109前店  050-5485-3597
# 41  貸切＆パーティーダイニング HASSO CAFFE with PRONTO 神保町店  050-5486-6451
# 42                          PRONTO 野村不動産天王洲ビル店  050-5492-7021
# 43                 羽根つき焼きおにぎり専門店＆LABAR gao－ガオ－  070-8419-2331
# 44                                   日高屋 戸越銀座店   03-3782-0466
# 45                                日高屋 高円寺北口駅前店   03-3223-2130
# 46                                   日高屋 蔵前駅前店   03-3865-5331
# 47                                 日高屋 大塚北口駅前店   03-3910-8857
# 48                                       松井製麺所  050-5486-9446
# 49                                 日高屋 高幡不動駅前店   042-592-2220
# 50                                 日高屋 押上四ツ目通店   03-5608-0302
# 51                                  日高屋 板橋駅西口店   03-3963-2455
# 52                                  日高屋 久米川南口店   042-395-6773
# 53                                   日高屋 春日駅前店   03-3814-6347
# 54                               日高屋 成城学園前駅北口店   03-3484-4777
# 55                                  日高屋 西大井駅前店   03-3778-2210
# 56                                   日高屋 大泉学園店   03-3978-5517
# 57                                   日高屋 新橋駅前店   03-3431-0025
# 58                                 日高屋 西日暮里東口店   03-3801-4678
# 59                                日高屋 三鷹南口中央通店   0422-47-7751
#
#            建物名
# 0     サンルイビル6F
# 1    テラススクエア1F
# 2
# 3
# 4
# 5     シャープ商事ビル
# 6
# 7       ba06ビル
# 8   ワールド四谷ビルB1
# 9
# 10
# 11       蕃ビル1F
# 12      晃正ビル1F
# 13        春日ビル
# 14
# 15
# 16    三幸産業第6ビル
# 17
# 18
# 19
# 20    サンルイビル6F
# 21   テラススクエア1F
# 22
# 23
# 24
# 25    シャープ商事ビル
# 26
# 27      ba06ビル
# 28  ワールド四谷ビルB1
# 29
# 30
# 31       蕃ビル1F
# 32      晃正ビル1F
# 33        春日ビル
# 34
# 35
# 36    三幸産業第6ビル
# 37
# 38
# 39
# 40    サンルイビル6F
# 41   テラススクエア1F
# 42
# 43
# 44
# 45    シャープ商事ビル
# 46
# 47      ba06ビル
# 48  ワールド四谷ビルB1
# 49
# 50
# 51       蕃ビル1F
# 52      晃正ビル1F
# 53        春日ビル
# 54
# 55
# 56    三幸産業第6ビル
# 57
# 58
# 59

# %%
#住所分割
url = 'https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW&p={}.format()'
max_page_index = 3
d_list_address = []
for i in range(max_page_index):
    acccess_url = url.format(i+1)

    r = requests.get(acccess_url)
    r.raise_for_status()

    soup = BeautifulSoup(r.content, 'lxml')

    for food_store in food_stores:
        store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
        page_url = food_store.find('a').get('href')

        page_r = requests.get(page_url, timeout=3)
        page_r.raise_for_status()

        page_soup = BeautifulSoup(page_r.content, 'lxml')
        store_address = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.region').text


        def divide_addess(address):
            matches = re.match(r'(...??[都道府県])((?:旭川|伊達|石狩|盛岡|奥州|田村|南相馬|那須塩原|東村山|武蔵村山|羽村|十日町|上越|富山|野々市|大町|蒲郡|四日市|姫路|大和郡山|廿日市|下松|岩国|田川|大村)市|.+?郡(?:玉村|大町|.+?)[町村]|.+?市.+?区|.+?[市区町村])(.+)' , address)
            matches[1]
            matches[2]
            matches[3]

            d_list_address.append({
                '都道府県':matches[1],
                '市町村':matches[2],
                '番地':matches[3]
            })

        if __name__ == '__main__':
            address = store_address
            divide_addess(address)

   
    
    


df1 = pd.DataFrame(d_list_address)
df1
# Out:
#    都道府県   市町村           番地
# 0   東京都   渋谷区     宇田川町26-2
# 1   東京都  千代田区     神田錦町3-22
# 2   東京都   品川区    東品川2-4-11
# 3   東京都   台東区      入谷2-3-3
# 4   東京都   品川区     平塚1-6-17
# 5   東京都   杉並区  高円寺北3-22-18
# 6   東京都   台東区    蔵前3-13-10
# 7   東京都   豊島区     北大塚2-2-2
# 8   東京都   新宿区      四谷4-3-1
# 9   東京都   日野市     高幡1000-8
# 10  東京都   墨田区     業平4-17-4
# 11  東京都   板橋区     板橋1-14-6
# 12  東京都  東村山市     栄町2-9-32
# 13  東京都   文京区     本郷4-24-5
# 14  東京都  世田谷区     成城6-11-9
# 15  東京都   品川区     西大井1-3-2
# 16  東京都   練馬区    東大泉1-37-2
# 17  東京都    港区    新橋3-25-19
# 18  東京都   荒川区  西日暮里5-13-11
# 19  東京都   三鷹市    下連雀3-34-3
# 20  東京都   渋谷区     宇田川町26-2
# 21  東京都  千代田区     神田錦町3-22
# 22  東京都   品川区    東品川2-4-11
# 23  東京都   台東区      入谷2-3-3
# 24  東京都   品川区     平塚1-6-17
# 25  東京都   杉並区  高円寺北3-22-18
# 26  東京都   台東区    蔵前3-13-10
# 27  東京都   豊島区     北大塚2-2-2
# 28  東京都   新宿区      四谷4-3-1
# 29  東京都   日野市     高幡1000-8
# 30  東京都   墨田区     業平4-17-4
# 31  東京都   板橋区     板橋1-14-6
# 32  東京都  東村山市     栄町2-9-32
# 33  東京都   文京区     本郷4-24-5
# 34  東京都  世田谷区     成城6-11-9
# 35  東京都   品川区     西大井1-3-2
# 36  東京都   練馬区    東大泉1-37-2
# 37  東京都    港区    新橋3-25-19
# 38  東京都   荒川区  西日暮里5-13-11
# 39  東京都   三鷹市    下連雀3-34-3
# 40  東京都   渋谷区     宇田川町26-2
# 41  東京都  千代田区     神田錦町3-22
# 42  東京都   品川区    東品川2-4-11
# 43  東京都   台東区      入谷2-3-3
# 44  東京都   品川区     平塚1-6-17
# 45  東京都   杉並区  高円寺北3-22-18
# 46  東京都   台東区    蔵前3-13-10
# 47  東京都   豊島区     北大塚2-2-2
# 48  東京都   新宿区      四谷4-3-1
# 49  東京都   日野市     高幡1000-8
# 50  東京都   墨田区     業平4-17-4
# 51  東京都   板橋区     板橋1-14-6
# 52  東京都  東村山市     栄町2-9-32
# 53  東京都   文京区     本郷4-24-5
# 54  東京都  世田谷区     成城6-11-9
# 55  東京都   品川区     西大井1-3-2
# 56  東京都   練馬区    東大泉1-37-2
# 57  東京都    港区    新橋3-25-19
# 58  東京都   荒川区  西日暮里5-13-11
# 59  東京都   三鷹市    下連雀3-34-3

# %%
#建物名
url = 'https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW&p={}.format()'
max_page_index = 3
d_list_building = []
for i in range(max_page_index):
    acccess_url = url.format(i+1)

    r = requests.get(acccess_url)
    r.raise_for_status()

    soup = BeautifulSoup(r.content, 'lxml')

    for food_store in food_stores:
        store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
        page_url = food_store.find('a').get('href')

        page_r = requests.get(page_url, timeout=3)
        page_r.raise_for_status()

        page_soup = BeautifulSoup(page_r.content, 'lxml')

        store_building = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.locality')

        if store_building:
            building_name = store_building.text
        else:
            building_name = ''

        d_list_building.append({
            '建物名':building_name
        })
        
df2 = pd.DataFrame(d_list_building)
df2
# Out:
#            建物名
# 0     サンルイビル6F
# 1    テラススクエア1F
# 2
# 3
# 4
# 5     シャープ商事ビル
# 6
# 7       ba06ビル
# 8   ワールド四谷ビルB1
# 9
# 10
# 11       蕃ビル1F
# 12      晃正ビル1F
# 13        春日ビル
# 14
# 15
# 16    三幸産業第6ビル
# 17
# 18
# 19
# 20    サンルイビル6F
# 21   テラススクエア1F
# 22
# 23
# 24
# 25    シャープ商事ビル
# 26
# 27      ba06ビル
# 28  ワールド四谷ビルB1
# 29
# 30
# 31       蕃ビル1F
# 32      晃正ビル1F
# 33        春日ビル
# 34
# 35
# 36    三幸産業第6ビル
# 37
# 38
# 39
# 40    サンルイビル6F
# 41   テラススクエア1F
# 42
# 43
# 44
# 45    シャープ商事ビル
# 46
# 47      ba06ビル
# 48  ワールド四谷ビルB1
# 49
# 50
# 51       蕃ビル1F
# 52      晃正ビル1F
# 53        春日ビル
# 54
# 55
# 56    三幸産業第6ビル
# 57
# 58
# 59

# %%
#お店のURLを取得

import requests
from bs4 import BeautifulSoup
from time import sleep

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.action_chains import ActionChains

options = Options()
options.add_argument("--headless")  # なしでもOK
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver.maximize_window()


def selenium(page_url):
    driver.get(page_url)
    sleep(3)

    try:
        shop_url_tag = driver.find_element_by_css_selector(
            '#info-table > table > tbody > tr:nth-child(9) > td > ul > li > a'
        )
        shop_url = shop_url_tag.get_attribute("href")
    except Exception as e:
        print('')


url = "https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW"

r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

stores = soup.find_all("div", class_="style_restaurant__SeIVn")

for store in stores:
    page_url = store.find("a").get("href")

    selenium(page_url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/isawashun/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# a
# a
# a
# a
# http://hidakaya.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://hidakaya.hiday.co.jp/

# %%
https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW&p={}.format()
max_page_index(3)
d_list = []
for i in range(max_page_index):
    acccess_url = url.format(i+1)
    

d_list.append({
    '店舗名':store_name,
    '電話番号':phone_number
    'メールアドレス':''
    '都道府県':address1,
    '市町村':address2,
    '番地':address3,
    '建物名':building_name,
    'URL':selenium(page_url)
    'SSL':SSL
})

df = pd.DataFrame(d_list)
df.to_csv('sample.csv', index=None, encoding='utf-8-sig')
