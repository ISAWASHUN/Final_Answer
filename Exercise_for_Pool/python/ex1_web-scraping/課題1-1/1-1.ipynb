# %%
#完成版
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.action_chains import ActionChains

url = 'https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW&p={}.format()'
max_page_index(3)
d_list = []
for i in range(max_page_index):
    acccess_url = url.format(i+1)

    r = requests.get(acccess_url)
    r.raise_for_status()

    soup = BeautifulSoup(r.content, 'lxml')

    food_stores =  soup.find_all('div', class_='style_restaurant__SeIVn')

    for food_store in food_stores:
        page_url = food_store.find('a').get('href')

        page_r = requests.get(page_url, timeout=3)
        page_r.raise_for_status()

        page_soup = BeautifulSoup(page_r.content, 'lxml')

        store_name = page_soup.select_one('#info-name').text

        phone_number = page_soup.select_one('#info-phone > td > ul > li:nth-child(1) > span.number').text


        store_building = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.locality')

        if store_building:
            building_name = store_building.text
        else:
            building_name = ''


        store_address = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.region').text
        
        def divide_addess(address):
            matches = re.match(r'(...??[都道府県])((?:旭川|伊達|石狩|盛岡|奥州|田村|南相馬|那須塩原|東村山|武蔵村山|羽村|十日町|上越|富山|野々市|大町|蒲郡|四日市|姫路|大和郡山|廿日市|下松|岩国|田川|大村)市|.+?郡(?:玉村|大町|.+?)[町村]|.+?市.+?区|.+?[市区町村])(.+)' , address)
            store_address1 = matches[1]
            store_address2 = matches[2]
            store_address3 = matches[3]



        if __name__ == '__main__':
            address = store_address
            divide_addess(address)


    options = Options()
    options.add_argument("--headless") 
    options.add_experimental_option("excludeSwitches", ["enable-logging"])
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    driver.maximize_window()


    def selenium(page_url):
        driver.get(page_url)
        sleep(3)

        try:
            shop_url_tag = driver.find_element_by_css_selector(
                '#info-table > table > tbody > tr:nth-child(9) > td > ul > li > a'
            )
            shop_url = shop_url_tag.get_attribute("href")
        except Exception as e:
            shop_url = ''



    for food_store in food_stores:
        page_url = food_store.find('a').get('href')

        selenium(page_url)




        d_list.append({
            '店舗名':store_name,
            '電話番号':phone_number
            'メールアドレス':''
            '都道府県':address1,
            '市町村':address2,
            '番地':address3,
            '建物名':building_name,
            'URL':selenium(page_url)
            'SSL':SSL
        })


df = pd.DataFrame(d_list)
df.to_csv('sample.csv', index=None, encoding='utf-8-sig')
# Out:
# {"a":"domadoma-taiyouent.com\/shibuyabunkamuradori","b":"https"}
#
#
#
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"http"}
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"hidakaya.hiday.co.jp\/","b":"https"}
# {"a":"www.hiday.co.jp\/","b":"http"}
# {"a":"www.hiday.co.jp\/","b":"http"}

# %%
#詳細ページのURLを取得
food_stores =  soup.find_all('div', class_='style_restaurant__SeIVn')

for food_store in food_stores:
    store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
    page_url = food_store.find('a').get('href')
    
    page_r = requests.get(page_url, timeout=3)
    page_r.raise_for_status()
    
    page_soup = BeautifulSoup(page_r.content, 'lxml')
    
    print(page_url)
# Out:
# https://r.gnavi.co.jp/g897448/
# https://r.gnavi.co.jp/ndjb72620000/
# https://r.gnavi.co.jp/pwcaw99j0000/
# https://r.gnavi.co.jp/d6sxtv1u0000/
# https://r.gnavi.co.jp/5sf33y6f0000/
# https://r.gnavi.co.jp/gjwzz8yz0000/
# https://r.gnavi.co.jp/m44rc7740000/
# https://r.gnavi.co.jp/a0yu0ksw0000/
# https://r.gnavi.co.jp/j9f9wcc00000/
# https://r.gnavi.co.jp/afvsf4070000/
# https://r.gnavi.co.jp/av590pyf0000/
# https://r.gnavi.co.jp/n21t342h0000/
# https://r.gnavi.co.jp/4zzpppjv0000/
# https://r.gnavi.co.jp/rvdx9cdf0000/
# https://r.gnavi.co.jp/29f8u6s10000/
# https://r.gnavi.co.jp/4135b2rz0000/
# https://r.gnavi.co.jp/g36un3xh0000/
# https://r.gnavi.co.jp/jjk372ky0000/
# https://r.gnavi.co.jp/n39kadnb0000/
# https://r.gnavi.co.jp/kss782pm0000/

# %%
#お店の名前
for food_store in food_stores:
    store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
    page_url = food_store.find('a').get('href')
    
    page_r = requests.get(page_url, timeout=3)
    page_r.raise_for_status()
    
    page_soup = BeautifulSoup(page_r.content, 'lxml')
    
    store_name = page_soup.select_one('#info-name').text
    print(store_name)
# Out:
# 居酒屋 土間土間 渋谷文化村通り109前店
# 貸切＆パーティーダイニング HASSO CAFFE with PRONTO 神保町店
# PRONTO 野村不動産天王洲ビル店
# 羽根つき焼きおにぎり専門店＆LABAR gao－ガオ－
# 日高屋 高円寺北口駅前店
# 日高屋 久米川南口店
# 日高屋 春日駅前店
# 日高屋 西大井駅前店
# 日高屋 三鷹南口中央通店
# 日高屋 北千住東口店
# 日高屋 大岡山店
# 日高屋 戸越銀座店
# 日高屋 新橋駅前店
# 日高屋 大塚北口駅前店
# 日高屋 西日暮里東口店
# 日高屋 清瀬南口店
# 日高屋 蔵前駅前店
# 日高屋 押上四ツ目通店
# 日高屋 雪が谷大塚南口店
# 日高屋 北千住西口きたろーど店

# %%
#お店の電話番号
for food_store in food_stores:
    store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
    page_url = food_store.find('a').get('href')
    
    page_r = requests.get(page_url, timeout=3)
    page_r.raise_for_status()
    
    page_soup = BeautifulSoup(page_r.content, 'lxml')
    
    phone_number = page_soup.select_one('#info-phone > td > ul > li:nth-child(1) > span.number').text
    print(phone_number)
# Out:
# 050-5485-3597
# 050-5486-6451
# 050-5492-7021
# 070-8419-2331
# 03-3223-2130
# 042-395-6773
# 03-3814-6347
# 03-3778-2210
# 0422-47-7751
# 03-3888-0155
# 03-5701-1450
# 03-3782-0466
# 03-3431-0025
# 03-3910-8857
# 03-3801-4678
# 042-492-6768
# 03-3865-5331
# 03-5608-0302
# 03-3726-6100
# 03-3881-5810

# %%
#住所分割
for food_store in food_stores:
    store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
    page_url = food_store.find('a').get('href')
    
    page_r = requests.get(page_url, timeout=3)
    page_r.raise_for_status()
    
    page_soup = BeautifulSoup(page_r.content, 'lxml')
    

    store_address = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.region').text
    

    def divide_addess(address):
        matches = re.match(r'(...??[都道府県])((?:旭川|伊達|石狩|盛岡|奥州|田村|南相馬|那須塩原|東村山|武蔵村山|羽村|十日町|上越|富山|野々市|大町|蒲郡|四日市|姫路|大和郡山|廿日市|下松|岩国|田川|大村)市|.+?郡(?:玉村|大町|.+?)[町村]|.+?市.+?区|.+?[市区町村])(.+)' , address)
        address1 = matches[1]
        address2 = matches[2]
        address3 = matches[3]

    if __name__ == '__main__':
        address = store_address
        divide_addess(address)
# Out:
# 東京都
# 渋谷区
# 宇田川町26-2
# 東京都
# 千代田区
# 神田錦町3-22
# 東京都
# 品川区
# 東品川2-4-11
# 東京都
# 台東区
# 入谷2-3-3
# 東京都
# 杉並区
# 高円寺北3-22-18
# 東京都
# 東村山市
# 栄町2-9-32
# 東京都
# 文京区
# 本郷4-24-5
# 東京都
# 品川区
# 西大井1-3-2
# 東京都
# 三鷹市
# 下連雀3-34-3
# 東京都
# 足立区
# 千住旭町40-22
# 東京都
# 大田区
# 北千束1-44-1
# 東京都
# 品川区
# 平塚1-6-17
# 東京都
# 港区
# 新橋3-25-19
# 東京都
# 豊島区
# 北大塚2-2-2
# 東京都
# 荒川区
# 西日暮里5-13-11
# 東京都
# 清瀬市
# 松山1-11-12
# 東京都
# 台東区
# 蔵前3-13-10
# 東京都
# 墨田区
# 業平4-17-4
# 東京都
# 大田区
# 南雪谷2-2-16
# 東京都
# 足立区
# 千住3-31-4

# %%
#建物名
for food_store in food_stores:
    store_name = food_store.select_one('div.style_title___HrjW > a > h2').text
    page_url = food_store.find('a').get('href')
    
    page_r = requests.get(page_url, timeout=3)
    page_r.raise_for_status()
    
    page_soup = BeautifulSoup(page_r.content, 'lxml')
    
    store_building = page_soup.select_one('#info-table > table > tbody > tr:nth-child(3) > td > p > span.locality')

    if store_building:
        building_name = store_building.text
    else:
        building_name = ''
        
    print(building_name)
# Out:
# サンルイビル6F
# テラススクエア1F
#
#
# シャープ商事ビル
# 晃正ビル1F
# 春日ビル
#
#
#
# リバーレプラザ大岡山1F
#
#
# ba06ビル
#
# 清瀬駅前ビル
#
#
#
# ライオンズプラザビル

# %%
#お店のURLを取得

import requests
from bs4 import BeautifulSoup
from time import sleep

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.action_chains import ActionChains

options = Options()
options.add_argument("--headless")  # なしでもOK
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver.maximize_window()


def selenium(page_url):
    driver.get(page_url)
    sleep(3)

    try:
        shop_url_tag = driver.find_element_by_css_selector(
            '#info-table > table > tbody > tr:nth-child(9) > td > ul > li > a'
        )
        shop_url = shop_url_tag.get_attribute("href")
    except Exception as e:
        pass


url = "https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW"

r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

stores = soup.find_all("div", class_="style_restaurant__SeIVn")

for store in stores:
    page_url = store.find("a").get("href")

    selenium(page_url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/isawashun/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# a
# a
# a
# a
# http://hidakaya.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://www.hiday.co.jp/
# http://www.hiday.co.jp/
# http://hidakaya.hiday.co.jp/
# http://hidakaya.hiday.co.jp/

# %%
https://r.gnavi.co.jp/area/tokyo/izakaya/rs/?sort=LOW&p={}.format()
max_page_index(3)
d_list = []
for i in range(max_page_index):
    acccess_url = url.format(i+1)
    

d_list.append({
    '店舗名':store_name,
    '電話番号':phone_number
    'メールアドレス':''
    '都道府県':address1,
    '市町村':address2,
    '番地':address3,
    '建物名':building_name,
    'URL':selenium(page_url)
    'SSL':SSL
})

df = pd.DataFrame(d_list)
df.to_csv('sample.csv', index=None, encoding='utf-8-sig')
